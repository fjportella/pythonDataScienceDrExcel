# %% [markdown]
# # Aula 3 - Funções Definidas pelo Usuário, Loop e Operadores Condicionais
#
# ## Funções Definidas pelo Usuário

# %%
import pandas as pd
import numpy as np

# %%
#base = pd.read_csv(r'E:\Users\quadr\Documents\Projetos\PA-Analytics\Python Básico para Data Science e Analytics\Curso\V2.0\Bases\Aula 3 e 4\train.csv')
base = pd.read_csv(r'/workspaces/pythonDataScienceDrExcel/Base de Dados/Aula 3 e 4/train.csv')

# %%
base
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
texto = 'Pedro Alves'

# %%
#Pega a primeira letra do nome + última letra e concatena com - Final
texto[0]+texto[-1]+' - Final'
# Out:
# 'Ps - Final'

# %%
#criando a mesma estrutura acima, mas dentro de uma função
def funcaopedro(texto):
    #essa função não está retornando na tela
    texto[0]+texto[-1]+ ' - Final'

# %%
funcaopedro('João Batista')

# %%
def funcaopedro(texto):
    #usar return para retornar na tela o resultado da função
    return(texto[0]+texto[-1]+ ' - Final')

# %%
funcaopedro('João Batista')
# Out:
# 'Ja - Final'

# %%
funcaopedro('Rodrigo Santana')
# Out:
# 'Ra - Final'

# %%
#Erro porque falta argumento na função
funcaopedro()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 funcaopedro()
#
# TypeError: funcaopedro() missing 1 required positional argument: 'texto'

# %%
#neste caso, foi definido um valor padrão (Pedro Alves) para quando não for passado argumento pelo usuário.
def funcaopedro(texto = 'Pedro Alves'):
    """ Retorna a Primeira e a Última Letra do texto passado + a string - teste"""
    
    return(texto[0]+texto[-1]+ ' - Final')

# %%
funcaopedro()
# Out:
# 'Ps - Final'

# %% [markdown]
# ### Função Lambda

# %%
#mesma função escrita acima, mas de forma simplificada usando Lambda
funcaopedro = lambda x: x[0]+x[-1] + ' - Final'

# %%
funcaopedro('Pedro Alves')
# Out:
# 'Ps - Final'

# %% [markdown]
# ## Loop

# %%
base
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# Criar uma coluna nova para armazenar o resultado

base['ColunaNova'] = pd.Series()

# %%
base
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  ColunaNova
# 0        0         A/5 21171   7.2500   NaN        S         NaN
# 1        0          PC 17599  71.2833   C85        C         NaN
# 2        0  STON/O2. 3101282   7.9250   NaN        S         NaN
# 3        0            113803  53.1000  C123        S         NaN
# 4        0            373450   8.0500   NaN        S         NaN
# ..     ...               ...      ...   ...      ...         ...
# 886      0            211536  13.0000   NaN        S         NaN
# 887      0            112053  30.0000   B42        S         NaN
# 888      2        W./C. 6607  23.4500   NaN        S         NaN
# 889      0            111369  30.0000  C148        C         NaN
# 890      0            370376   7.7500   NaN        Q         NaN
#
# [891 rows x 13 columns]

# %%
base.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
base

# %%
# Fazendo a operação repetida para a coluna inteira

for i in base.index:
    base['ColunaNova'][i] = funcaopedro(base['Name'][i])
# Out:
# C:\Users\quadr\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\quadr\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
base
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  ColunaNova
# 0        0         A/5 21171   7.2500   NaN        S  Bs - Final
# 1        0          PC 17599  71.2833   C85        C  C) - Final
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Ha - Final
# 3        0            113803  53.1000  C123        S  F) - Final
# 4        0            373450   8.0500   NaN        S  Ay - Final
# ..     ...               ...      ...   ...      ...         ...
# 886      0            211536  13.0000   NaN        S  Ms - Final
# 887      0            112053  30.0000   B42        S  Gh - Final
# 888      2        W./C. 6607  23.4500   NaN        S  J" - Final
# 889      0            111369  30.0000  C148        C  Bl - Final
# 890      0            370376   7.7500   NaN        Q  Dk - Final
#
# [891 rows x 13 columns]

# %%
# Dica - Função Apply (para base de dados muito grande). funciona só com função lambda

base['ColunaNova2'] = base['Name'].apply(lambda x: funcaopedro(x))

# %%
base
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  ColunaNova ColunaNova2
# 0        0         A/5 21171   7.2500   NaN        S  Bs - Final  Bs - Final
# 1        0          PC 17599  71.2833   C85        C  C) - Final  C) - Final
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Ha - Final  Ha - Final
# 3        0            113803  53.1000  C123        S  F) - Final  F) - Final
# 4        0            373450   8.0500   NaN        S  Ay - Final  Ay - Final
# ..     ...               ...      ...   ...      ...         ...         ...
# 886      0            211536  13.0000   NaN        S  Ms - Final  Ms - Final
# 887      0            112053  30.0000   B42        S  Gh - Final  Gh - Final
# 888      2        W./C. 6607  23.4500   NaN        S  J" - Final  J" - Final
# 889      0            111369  30.0000  C148        C  Bl - Final  Bl - Final
# 890      0            370376   7.7500   NaN        Q  Dk - Final  Dk - Final
#
# [891 rows x 14 columns]

# %% [markdown]
# ## Operadores Condicionais

# %%
base
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  ColunaNova ColunaNova2
# 0        0         A/5 21171   7.2500   NaN        S  Ps - Final  Bs - Final
# 1        0          PC 17599  71.2833   C85        C  C5 - Final  C) - Final
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Ps - Final  Ha - Final
# 3        0            113803  53.1000  C123        S  C3 - Final  F) - Final
# 4        0            373450   8.0500   NaN        S  Ps - Final  Ay - Final
# ..     ...               ...      ...   ...      ...         ...         ...
# 886      0            211536  13.0000   NaN        S  Ps - Final  Ms - Final
# 887      0            112053  30.0000   B42        S  B2 - Final  Gh - Final
# 888      2        W./C. 6607  23.4500   NaN        S  Ps - Final  J" - Final
# 889      0            111369  30.0000  C148        C  C8 - Final  Bl - Final
# 890      0            370376   7.7500   NaN        Q  Ps - Final  Dk - Final
#
# [891 rows x 14 columns]

# %%
base['ColunaNova3'] = pd.Series()

# %%
base
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  ColunaNova ColunaNova2  \
# 0        0         A/5 21171   7.2500   NaN        S  Ps - Final  Bs - Final
# 1        0          PC 17599  71.2833   C85        C  C5 - Final  C) - Final
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Ps - Final  Ha - Final
# 3        0            113803  53.1000  C123        S  C3 - Final  F) - Final
# 4        0            373450   8.0500   NaN        S  Ps - Final  Ay - Final
# ..     ...               ...      ...   ...      ...         ...         ...
# 886      0            211536  13.0000   NaN        S  Ps - Final  Ms - Final
# 887      0            112053  30.0000   B42        S  B2 - Final  Gh - Final
# 888      2        W./C. 6607  23.4500   NaN        S  Ps - Final  J" - Final
# 889      0            111369  30.0000  C148        C  C8 - Final  Bl - Final
# 890      0            370376   7.7500   NaN        Q  Ps - Final  Dk - Final
#
#      ColunaNova3
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 886          NaN
# 887          NaN
# 888          NaN
# 889          NaN
# 890          NaN
#
# [891 rows x 15 columns]

# %%
for i in base.index:
    if base['Name'][i][0] == 'B':
        base['ColunaNova3'][i] = funcaopedro(base['Name'][i])
    elif base['Name'][i][0] == 'C':
        base['ColunaNova3'][i] = funcaopedro(base['Name'][i])
    else:
        pass
# Out:
# C:\Users\quadr\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\quadr\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
base
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  ColunaNova ColunaNova2  \
# 0        0         A/5 21171   7.2500   NaN        S  Ps - Final  Bs - Final
# 1        0          PC 17599  71.2833   C85        C  C5 - Final  C) - Final
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Ps - Final  Ha - Final
# 3        0            113803  53.1000  C123        S  C3 - Final  F) - Final
# 4        0            373450   8.0500   NaN        S  Ps - Final  Ay - Final
# ..     ...               ...      ...   ...      ...         ...         ...
# 886      0            211536  13.0000   NaN        S  Ps - Final  Ms - Final
# 887      0            112053  30.0000   B42        S  B2 - Final  Gh - Final
# 888      2        W./C. 6607  23.4500   NaN        S  Ps - Final  J" - Final
# 889      0            111369  30.0000  C148        C  C8 - Final  Bl - Final
# 890      0            370376   7.7500   NaN        Q  Ps - Final  Dk - Final
#
#     ColunaNova3
# 0    Bs - Final
# 1    C) - Final
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 886         NaN
# 887         NaN
# 888         NaN
# 889  Bl - Final
# 890         NaN
#
# [891 rows x 15 columns]

# %%
base['ColunaNova4'] = pd.Series()

contador = 0
while contador <5:
    base['ColunaNova4'][contador] = funcaopedro(base['Name'][contador])
    contador = contador + 1
# Out:
# C:\Users\quadr\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
base.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked  ColunaNova ColunaNova2  \
# 0      0         A/5 21171   7.2500   NaN        S  Ps - Final  Bs - Final
# 1      0          PC 17599  71.2833   C85        C  C5 - Final  C) - Final
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Ps - Final  Ha - Final
# 3      0            113803  53.1000  C123        S  C3 - Final  F) - Final
# 4      0            373450   8.0500   NaN        S  Ps - Final  Ay - Final
# 5      0            330877   8.4583   NaN        Q  Ps - Final  Ms - Final
#
#   ColunaNova3 ColunaNova4
# 0  Bs - Final  Bs - Final
# 1  C) - Final  C) - Final
# 2         NaN  Ha - Final
# 3         NaN  F) - Final
# 4         NaN  Ay - Final
# 5         NaN         NaN

# %% [markdown]
# ## Tolerância a Erros

# %%
base
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  ColunaNova ColunaNova2  \
# 0        0         A/5 21171   7.2500   NaN        S  Ps - Final  Bs - Final
# 1        0          PC 17599  71.2833   C85        C  C5 - Final  C) - Final
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Ps - Final  Ha - Final
# 3        0            113803  53.1000  C123        S  C3 - Final  F) - Final
# 4        0            373450   8.0500   NaN        S  Ps - Final  Ay - Final
# ..     ...               ...      ...   ...      ...         ...         ...
# 886      0            211536  13.0000   NaN        S  Ps - Final  Ms - Final
# 887      0            112053  30.0000   B42        S  B2 - Final  Gh - Final
# 888      2        W./C. 6607  23.4500   NaN        S  Ps - Final  J" - Final
# 889      0            111369  30.0000  C148        C  C8 - Final  Bl - Final
# 890      0            370376   7.7500   NaN        Q  Ps - Final  Dk - Final
#
#     ColunaNova3 ColunaNova4
# 0    Bs - Final  Bs - Final
# 1    C) - Final  C) - Final
# 2           NaN  Ha - Final
# 3           NaN  F) - Final
# 4           NaN  Ay - Final
# ..          ...         ...
# 886         NaN         NaN
# 887         NaN         NaN
# 888         NaN         NaN
# 889  Bl - Final         NaN
# 890         NaN         NaN
#
# [891 rows x 16 columns]

# %%
# Usamos o operador Try quando queremos rodar um código com tolerância a erros

# Definindo novamente a função Pedro. Não terá mais o valor padrão

def funcaopedro(texto):
    
    return(texto[0]+texto[-1]+ ' - Final')


# Fazendo a operação repetida para a coluna inteira

for i in base.index:
    base['ColunaNova5'][i] = funcaopedro(base['Cabin'][i]) #vai dar erro, porque há valores vazios
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-a8ca9b1898c2> in <module>
#      11
#      12 for i in base.index:
# ---> 13     base['ColunaNova5'][i] = funcaopedro(base['Cabin'][i])
#
# <ipython-input-42-a8ca9b1898c2> in funcaopedro(texto)
#       5 def funcaopedro(texto):
#       6
# ----> 7     return(texto[0]+texto[-1]+ ' - Final')
#       8
#       9
#
# TypeError: 'float' object is not subscriptable

# %%
# Fazendo a operação repetida para a coluna inteira
#usando try para condições de erros
base['ColunaNova5'] = pd.Series()

for i in base.index:
    try:
        base['ColunaNova5'][i] = funcaopedro(base['Cabin'][i])
    except:
        #print('Erro no índice ' + str(i))
        base['ColunaNova5'][i] = funcaopedro('Pedro Alves')
# Out:
# C:\Users\quadr\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\quadr\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
base
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  ColunaNova ColunaNova2  \
# 0        0         A/5 21171   7.2500   NaN        S  Ps - Final  Bs - Final
# 1        0          PC 17599  71.2833   C85        C  C5 - Final  C) - Final
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Ps - Final  Ha - Final
# 3        0            113803  53.1000  C123        S  C3 - Final  F) - Final
# 4        0            373450   8.0500   NaN        S  Ps - Final  Ay - Final
# ..     ...               ...      ...   ...      ...         ...         ...
# 886      0            211536  13.0000   NaN        S  Ps - Final  Ms - Final
# 887      0            112053  30.0000   B42        S  B2 - Final  Gh - Final
# 888      2        W./C. 6607  23.4500   NaN        S  Ps - Final  J" - Final
# 889      0            111369  30.0000  C148        C  C8 - Final  Bl - Final
# 890      0            370376   7.7500   NaN        Q  Ps - Final  Dk - Final
#
#     ColunaNova3 ColunaNova4 ColunaNova5
# 0    Bs - Final  Bs - Final  Ps - Final
# 1    C) - Final  C) - Final  C5 - Final
# 2           NaN  Ha - Final  Ps - Final
# 3           NaN  F) - Final  C3 - Final
# 4           NaN  Ay - Final  Ps - Final
# ..          ...         ...         ...
# 886         NaN         NaN  Ps - Final
# 887         NaN         NaN  B2 - Final
# 888         NaN         NaN  Ps - Final
# 889  Bl - Final         NaN  C8 - Final
# 890         NaN         NaN  Ps - Final
#
# [891 rows x 17 columns]
